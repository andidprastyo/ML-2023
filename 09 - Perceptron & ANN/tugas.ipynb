# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import confusion_matrix, accuracy_score
from collections import Counter
import seaborn as sns

# %% [markdown]
# ### Load MNIST Dataset

# %%
mnist = fetch_openml('mnist_784', version=1)
X, y = mnist.data, mnist.target.astype(int)
# Out:
# /home/ubuntu/.local/lib/python3.10/site-packages/sklearn/datasets/_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
print(mnist.DESCR)
# Out:
# **Author**: Yann LeCun, Corinna Cortes, Christopher J.C. Burges
# **Source**: [MNIST Website](http://yann.lecun.com/exdb/mnist/) - Date unknown
# **Please cite**:
#
# The MNIST database of handwritten digits with 784 features, raw data available at: http://yann.lecun.com/exdb/mnist/. It can be split in a training set of the first 60,000 examples, and a test set of 10,000 examples
#
# It is a subset of a larger set available from NIST. The digits have been size-normalized and centered in a fixed-size image. It is a good database for people who want to try learning techniques and pattern recognition methods on real-world data while spending minimal efforts on preprocessing and formatting. The original black and white (bilevel) images from NIST were size normalized to fit in a 20x20 pixel box while preserving their aspect ratio. The resulting images contain grey levels as a result of the anti-aliasing technique used by the normalization algorithm. the images were centered in a 28x28 image by computing the center of mass of the pixels, and translating the image so as to position this point at the center of the 28x28 field.
#
# With some classification methods (particularly template-based methods, such as SVM and K-nearest neighbors), the error rate improves when the digits are centered by bounding box rather than center of mass. If you do this kind of pre-processing, you should report it in your publications. The MNIST database was constructed from NIST's NIST originally designated SD-3 as their training set and SD-1 as their test set. However, SD-3 is much cleaner and easier to recognize than SD-1. The reason for this can be found on the fact that SD-3 was collected among Census Bureau employees, while SD-1 was collected among high-school students. Drawing sensible conclusions from learning experiments requires that the result be independent of the choice of training set and test among the complete set of samples. Therefore it was necessary to build a new database by mixing NIST's datasets.
#
# The MNIST training set is composed of 30,000 patterns from SD-3 and 30,000 patterns from SD-1. Our test set was composed of 5,000 patterns from SD-3 and 5,000 patterns from SD-1. The 60,000 pattern training set contained examples from approximately 250 writers. We made sure that the sets of writers of the training set and test set were disjoint. SD-1 contains 58,527 digit images written by 500 different writers. In contrast to SD-3, where blocks of data from each writer appeared in sequence, the data in SD-1 is scrambled. Writer identities for SD-1 is available and we used this information to unscramble the writers. We then split SD-1 in two: characters written by the first 250 writers went into our new training set. The remaining 250 writers were placed in our test set. Thus we had two sets with nearly 30,000 examples each. The new training set was completed with enough examples from SD-3, starting at pattern # 0, to make a full set of 60,000 training patterns. Similarly, the new test set was completed with SD-3 examples starting at pattern # 35,000 to make a full set with 60,000 test patterns. Only a subset of 10,000 test images (5,000 from SD-1 and 5,000 from SD-3) is available on this site. The full 60,000 sample training set is available.
#
# Downloaded from openml.org.

# %% [markdown]
# ### Data Preprocessing

# %%
x, y = mnist.data, mnist.target.astype(int)
class_counts = Counter(y)
print(class_counts)
counts = [class_counts[i] for i in range(10)]
class_labels = [str(i) for i in range(10)]

plt.bar(class_labels, counts)
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.title('Class Distribution in MNIST Dataset')
plt.show()
# Out:
# Counter({1: 7877, 7: 7293, 3: 7141, 2: 6990, 9: 6958, 0: 6903, 6: 6876, 8: 6825, 4: 6824, 5: 6313})

# %% [markdown]
# ### Split Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
x_convert = X.values.astype(int)

plt.figure(figsize=(10, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_convert[i].reshape(28, 28), cmap='gray')
    plt.title(f"Label: {y[i]}")
    plt.axis('off')  # Turn off axis labels

plt.suptitle('First 10 Images from MNIST Dataset')
plt.show()

# %% [markdown]
# ### Normalisasi

# %%
X_train = tf.keras.utils.normalize(X_train, axis=1)
X_test = tf.keras.utils.normalize(X_test, axis=1)

X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### ANN Modelling

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Building layer

# %%
ann.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784, )))
ann.add(tf.keras.layers.Dense(units=128, activation='relu'))
ann.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 118282 (462.04 KB)
# Trainable params: 118282 (462.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Compiling ANN Model

# %%
ann.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Fitting

# %%
ann.fit(X_train, y_train, epochs=50, batch_size=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
#  31/560 [>.............................] - ETA: 1s - loss: 0.1839 - accuracy: 0.9523
# 2023-10-31 13:11:13.453672: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 351232000 exceeds 10% of free system memory.
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1750 - accuracy: 0.9490 - val_loss: 0.1845 - val_accuracy: 0.9446
# Epoch 2/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1748 - accuracy: 0.9483 - val_loss: 0.1807 - val_accuracy: 0.9461
# Epoch 3/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1717 - accuracy: 0.9496 - val_loss: 0.1789 - val_accuracy: 0.9469
# Epoch 4/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1710 - accuracy: 0.9494 - val_loss: 0.1828 - val_accuracy: 0.9446
# Epoch 5/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1683 - accuracy: 0.9505 - val_loss: 0.1773 - val_accuracy: 0.9466
# Epoch 6/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1648 - accuracy: 0.9522 - val_loss: 0.1849 - val_accuracy: 0.9447
# Epoch 7/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1631 - accuracy: 0.9519 - val_loss: 0.1698 - val_accuracy: 0.9505
# Epoch 8/50
# 560/560 [==============================] - 2s 4ms/step - loss: 0.1591 - accuracy: 0.9534 - val_loss: 0.1653 - val_accuracy: 0.9507
# Epoch 9/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1579 - accuracy: 0.9540 - val_loss: 0.1683 - val_accuracy: 0.9504
# Epoch 10/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1559 - accuracy: 0.9538 - val_loss: 0.1642 - val_accuracy: 0.9511
# Epoch 11/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1539 - accuracy: 0.9545 - val_loss: 0.1759 - val_accuracy: 0.9474
# Epoch 12/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1507 - accuracy: 0.9556 - val_loss: 0.1597 - val_accuracy: 0.9522
# Epoch 13/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1496 - accuracy: 0.9554 - val_loss: 0.1611 - val_accuracy: 0.9516
# Epoch 14/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1471 - accuracy: 0.9563 - val_loss: 0.1689 - val_accuracy: 0.9500
# Epoch 15/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1448 - accuracy: 0.9571 - val_loss: 0.1574 - val_accuracy: 0.9533
# Epoch 16/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1438 - accuracy: 0.9580 - val_loss: 0.1566 - val_accuracy: 0.9541
# Epoch 17/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1415 - accuracy: 0.9581 - val_loss: 0.1525 - val_accuracy: 0.9556
# Epoch 18/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1388 - accuracy: 0.9590 - val_loss: 0.1478 - val_accuracy: 0.9547
# Epoch 19/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1398 - accuracy: 0.9584 - val_loss: 0.1582 - val_accuracy: 0.9523
# Epoch 20/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1363 - accuracy: 0.9593 - val_loss: 0.1496 - val_accuracy: 0.9556
# Epoch 21/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1355 - accuracy: 0.9596 - val_loss: 0.1530 - val_accuracy: 0.9551
# Epoch 22/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1331 - accuracy: 0.9600 - val_loss: 0.1461 - val_accuracy: 0.9564
# Epoch 23/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1307 - accuracy: 0.9611 - val_loss: 0.1427 - val_accuracy: 0.9574
# Epoch 24/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1295 - accuracy: 0.9613 - val_loss: 0.1481 - val_accuracy: 0.9558
# Epoch 25/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1275 - accuracy: 0.9616 - val_loss: 0.1542 - val_accuracy: 0.9543
# Epoch 26/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1268 - accuracy: 0.9622 - val_loss: 0.1485 - val_accuracy: 0.9559
# Epoch 27/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1255 - accuracy: 0.9624 - val_loss: 0.1464 - val_accuracy: 0.9558
# Epoch 28/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1243 - accuracy: 0.9631 - val_loss: 0.1498 - val_accuracy: 0.9551
# Epoch 29/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1239 - accuracy: 0.9635 - val_loss: 0.1401 - val_accuracy: 0.9577
# Epoch 30/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1215 - accuracy: 0.9635 - val_loss: 0.1376 - val_accuracy: 0.9582
# Epoch 31/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1193 - accuracy: 0.9647 - val_loss: 0.1479 - val_accuracy: 0.9538
# Epoch 32/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1185 - accuracy: 0.9644 - val_loss: 0.1405 - val_accuracy: 0.9574
# Epoch 33/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1176 - accuracy: 0.9641 - val_loss: 0.1365 - val_accuracy: 0.9592
# Epoch 34/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1165 - accuracy: 0.9656 - val_loss: 0.1350 - val_accuracy: 0.9594
# Epoch 35/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1157 - accuracy: 0.9652 - val_loss: 0.1335 - val_accuracy: 0.9589
# Epoch 36/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1130 - accuracy: 0.9661 - val_loss: 0.1415 - val_accuracy: 0.9573
# Epoch 37/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1118 - accuracy: 0.9668 - val_loss: 0.1325 - val_accuracy: 0.9595
# Epoch 38/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1112 - accuracy: 0.9666 - val_loss: 0.1398 - val_accuracy: 0.9571
# Epoch 39/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1111 - accuracy: 0.9665 - val_loss: 0.1302 - val_accuracy: 0.9608
# Epoch 40/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1109 - accuracy: 0.9658 - val_loss: 0.1422 - val_accuracy: 0.9572
# Epoch 41/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1087 - accuracy: 0.9676 - val_loss: 0.1280 - val_accuracy: 0.9613
# Epoch 42/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1061 - accuracy: 0.9682 - val_loss: 0.1381 - val_accuracy: 0.9579
# Epoch 43/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1050 - accuracy: 0.9682 - val_loss: 0.1349 - val_accuracy: 0.9594
# Epoch 44/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1048 - accuracy: 0.9686 - val_loss: 0.1267 - val_accuracy: 0.9626
# Epoch 45/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1043 - accuracy: 0.9681 - val_loss: 0.1288 - val_accuracy: 0.9607
# Epoch 46/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1029 - accuracy: 0.9691 - val_loss: 0.1634 - val_accuracy: 0.9494
# Epoch 47/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1023 - accuracy: 0.9689 - val_loss: 0.1271 - val_accuracy: 0.9625
# Epoch 48/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1007 - accuracy: 0.9696 - val_loss: 0.1264 - val_accuracy: 0.9609
# Epoch 49/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.1010 - accuracy: 0.9689 - val_loss: 0.1294 - val_accuracy: 0.9605
# Epoch 50/50
# 560/560 [==============================] - 2s 3ms/step - loss: 0.0988 - accuracy: 0.9707 - val_loss: 0.1290 - val_accuracy: 0.9608

# %% [markdown]
# ### Evaluating

# %%
loss, accuracy = ann.evaluate(X_test, y_test)

print(f"Loss: {loss}")
print(f"Accuracy: {accuracy}")
# Out:
# 438/438 [==============================] - 1s 2ms/step - loss: 0.1290 - accuracy: 0.9608
# Loss: 0.1290474832057953
# Accuracy: 0.9607856869697571

# %% [markdown]
# ### Confusion Matrix

# %%
y_pred = ann.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)

cm = confusion_matrix(y_test, y_pred)
cm_percent = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100

fig, ax = plt.subplots(figsize=(10, 10))

sns.heatmap(cm_percent, annot=True, ax=ax, cmap='Blues', fmt='.2f', cbar=False)
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Confusion Matrix(%)')

class_names = [str(i) for i in range(10)]
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)

plt.show()
# Out:
# 438/438 [==============================] - 1s 1ms/step
