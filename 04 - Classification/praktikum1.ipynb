# %% [markdown]
# ### Import libraries

# %%
# For data manipulation
import numpy as np 
import pandas as pd
from sklearn.datasets import make_blobs

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns 
from ipywidgets import interact, interactive, fixed

# For svm modelling
from sklearn.svm import SVC

# %% [markdown]
# ### Visualize the Dataset

# %%
X, y = make_blobs(n_samples=100, centers=2, random_state=0, cluster_std=0.5)
plt.scatter(X[:,0], X[:,1], c=y, s=50, cmap='autumn')

# %%
dt = np.concatenate((X, y.reshape(-1,1)), axis=1)

# %%
dt
# Out:
# array([[ 3.1368855 ,  1.56592763,  1.        ],
#        [ 1.4815332 ,  0.67875364,  1.        ],
#        [ 0.3498724 ,  4.69253251,  0.        ],
#        [ 0.5323772 ,  3.31338909,  0.        ],
#        [ 2.64928242,  1.05613497,  1.        ],
#        [ 1.2091013 ,  3.53566548,  0.        ],
#        [ 0.99914934,  4.2101954 ,  0.        ],
#        [ 3.01673853,  1.63792106,  1.        ],
#        [ 0.78260667,  4.15263595,  0.        ],
#        [ 1.65356269,  0.55288877,  1.        ],
#        [ 0.802314  ,  4.38196181,  0.        ],
#        [ 1.8706766 ,  0.77797407,  1.        ],
#        [ 1.08040757,  4.79210685,  0.        ],
#        [ 0.5226209 ,  4.32976003,  0.        ],
#        [ 1.92126584,  1.29889186,  1.        ],
#        [ 3.24683991,  1.3699034 ,  1.        ],
#        [ 2.61858548,  0.35769791,  1.        ],
#        [ 0.64003985,  4.12401075,  0.        ],
#        [ 1.39731382,  0.66687136,  1.        ],
#        [ 1.67030948,  1.16728826,  1.        ],
#        [ 1.05374379,  4.49286859,  0.        ],
#        [ 0.82049381,  4.33187   ,  0.        ],
#        [ 1.68548602,  1.66917096,  1.        ],
#        [ 0.39369516,  4.75420057,  0.        ],
#        [ 2.31690585,  0.81189049,  1.        ],
#        [ 0.92466065,  4.50908658,  0.        ],
#        [ 1.68289011,  0.48444439,  1.        ],
#        [ 0.98152009,  5.19672257,  0.        ],
#        [ 1.19820169,  4.47062449,  0.        ],
#        [ 2.20438661,  1.56085661,  1.        ],
#        [ 2.24348029,  0.34796326,  1.        ],
#        [ 1.00952869,  4.45502328,  0.        ],
#        [ 1.50307585,  0.9237462 ,  1.        ],
#        [ 2.25327088,  0.35113291,  1.        ],
#        [ 1.83769075,  1.82229552,  1.        ],
#        [ 1.56565986,  4.21382491,  0.        ],
#        [ 1.71810119,  0.91357894,  1.        ],
#        [ 2.02114672,  1.75433502,  1.        ],
#        [ 1.54597042,  3.68637442,  0.        ],
#        [ 1.30963873,  1.11735951,  1.        ],
#        [ 0.4519936 ,  3.59377836,  0.        ],
#        [ 1.74265969,  5.03846671,  0.        ],
#        [ 0.12313498,  5.27917503,  0.        ],
#        [ 1.1774409 ,  3.96138228,  0.        ],
#        [ 1.46870582,  1.86947425,  1.        ],
#        [ 2.13860427,  1.21517938,  1.        ],
#        [ 2.03562611,  0.31361691,  1.        ],
#        [ 1.87827057,  0.21018801,  1.        ],
#        [ 0.16117091,  4.53517846,  0.        ],
#        [ 0.77468161,  4.91500986,  0.        ],
#        [ 2.00604126,  0.56592452,  1.        ],
#        [ 1.40883907,  1.03118909,  1.        ],
#        [ 1.72039618,  5.25173192,  0.        ],
#        [ 1.15445328,  4.65707391,  0.        ],
#        [ 2.11114739,  3.57660449,  0.        ],
#        [ 1.03972612,  4.50478201,  0.        ],
#        [ 1.91784543,  3.6299078 ,  0.        ],
#        [ 1.82750127,  0.90640324,  1.        ],
#        [ 2.51569693,  1.05702749,  1.        ],
#        [ 2.36788325,  0.09663483,  1.        ],
#        [ 1.73734448,  1.23588031,  1.        ],
#        [ 1.45131429,  4.22810872,  0.        ],
#        [ 0.44089377,  4.83101319,  0.        ],
#        [ 2.3914149 ,  1.10139458,  1.        ],
#        [ 1.04829186,  5.03092408,  0.        ],
#        [ 1.8062513 ,  1.86242969,  1.        ],
#        [ 0.5408715 ,  4.0143625 ,  0.        ],
#        [ 1.91004907,  3.81514839,  0.        ],
#        [ 2.60509732,  1.22529553,  1.        ],
#        [ 1.40848818,  3.93270482,  0.        ],
#        [ 1.13280393,  3.87673946,  0.        ],
#        [ 1.84845803,  0.52393625,  1.        ],
#        [ 2.989047  ,  1.35068599,  1.        ],
#        [ 1.34081536,  4.36827878,  0.        ],
#        [ 0.56969694,  3.44064603,  0.        ],
#        [ 0.65910903,  4.12241674,  0.        ],
#        [ 1.5381461 ,  1.23846092,  1.        ],
#        [ 2.36230721,  1.358767  ,  1.        ],
#        [ 0.72144399,  4.08475018,  0.        ],
#        [ 0.96217896,  4.51795326,  0.        ],
#        [ 1.62465468,  1.85269614,  1.        ],
#        [ 1.06498315,  4.10289686,  0.        ],
#        [ 0.34102758,  4.78848568,  0.        ],
#        [ 1.35678894,  4.36462484,  0.        ],
#        [ 0.72086751,  3.71347124,  0.        ],
#        [ 0.5285368 ,  4.49723858,  0.        ],
#        [ 2.52889351,  0.82015861,  1.        ],
#        [ 1.59141542,  4.90497725,  0.        ],
#        [ 1.70798359,  0.82284639,  1.        ],
#        [ 2.34356293,  0.79351428,  1.        ],
#        [ 2.4411628 ,  1.30941574,  1.        ],
#        [ 2.48368283,  0.57215086,  1.        ],
#        [ 1.59885641,  1.4561718 ,  1.        ],
#        [ 1.55515985,  0.12527811,  1.        ],
#        [ 1.72330962,  4.2012082 ,  0.        ],
#        [-0.30022483,  4.63059663,  0.        ],
#        [ 1.73345832, -0.21403792,  1.        ],
#        [ 2.52997792,  0.94143928,  1.        ],
#        [ 0.16932115,  4.19741719,  0.        ],
#        [ 1.44254976,  1.31984515,  1.        ]])

# %%
df = pd.DataFrame(dt, columns=['x1', 'x2', 'y'])
df
# Out:
#           x1        x2    y
# 0   3.136885  1.565928  1.0
# 1   1.481533  0.678754  1.0
# 2   0.349872  4.692533  0.0
# 3   0.532377  3.313389  0.0
# 4   2.649282  1.056135  1.0
# ..       ...       ...  ...
# 95 -0.300225  4.630597  0.0
# 96  1.733458 -0.214038  1.0
# 97  2.529978  0.941439  1.0
# 98  0.169321  4.197417  0.0
# 99  1.442550  1.319845  1.0
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Data Separator

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')
plt.plot([0.6], [2.1], 'x', color='red', markeredgewidth=2, markersize=10)

for m, b in [(1, 0.65), (0.5, 1.6), (-0.2, 2.9)]:
    plt.plot(xfit, m * xfit + b, '-k')

plt.xlim(-1, 3.5)
# Out:
# (-1.0, 3.5)

# %% [markdown]
# ### Plot the Margin

# %%
xfit = np.linspace(-1, 3.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='autumn')

for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]:
    yfit = m * xfit + b
    plt.plot(xfit, yfit, '-k')
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',
                     color='#AAAAAA', alpha=0.4)

plt.xlim(-1, 3.5)
# Out:
# (-1.0, 3.5)

# %% [markdown]
# ### Fitting SVM

# %%
model = SVC(kernel='linear', C=1E10)
model.fit(X, y)
# Out:
# SVC(C=10000000000.0, kernel='linear')

# %% [markdown]
# ### Plot the Fitting Data
